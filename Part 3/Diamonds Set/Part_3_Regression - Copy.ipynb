# %%
import numpy as np
import pandas as pd
import os
import matplotlib.pyplot as plt
import random

# %%
df = pd.read_csv(r'C:\Users\stany\OneDrive\Desktop\Diamonds Set\diamonds.csv')
print(df)
# Out:
#        Unnamed: 0  carat        cut color clarity  depth  table  price     x  \
# 0               1   0.23      Ideal     E     SI2   61.5   55.0    326  3.95
# 1               2   0.21    Premium     E     SI1   59.8   61.0    326  3.89
# 2               3   0.23       Good     E     VS1   56.9   65.0    327  4.05
# 3               4   0.29    Premium     I     VS2   62.4   58.0    334  4.20
# 4               5   0.31       Good     J     SI2   63.3   58.0    335  4.34
# ...           ...    ...        ...   ...     ...    ...    ...    ...   ...
# 53935       53936   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75
# 53936       53937   0.72       Good     D     SI1   63.1   55.0   2757  5.69
# 53937       53938   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66
# 53938       53939   0.86    Premium     H     SI2   61.0   58.0   2757  6.15
# 53939       53940   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83
#
#           y     z
# 0      3.98  2.43
# 1      3.84  2.31
# 2      4.07  2.31
# 3      4.23  2.63
# 4      4.35  2.75
# ...     ...   ...
# 53935  5.76  3.50
# 53936  5.75  3.61
# 53937  5.68  3.56
# 53938  6.12  3.74
# 53939  5.87  3.64
#
# [53940 rows x 11 columns]

# %%
# df = pd.read_csv(r'C:\Users\stany\OneDrive\Desktop\Air Quality\AirQualityUCI.csv')
# print(df)
print(df.head())
# Out:
#    Unnamed: 0  carat      cut color clarity  depth  table  price     x     y  \
# 0           1   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98
# 1           2   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84
# 2           3   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07
# 3           4   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23
# 4           5   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35
#
#       z
# 0  2.43
# 1  2.31
# 2  2.31
# 3  2.63
# 4  2.75

# %%
df.dtypes
# Out:
# Unnamed: 0      int64
# carat         float64
# cut            object
# color          object
# clarity        object
# depth         float64
# table         float64
# price           int64
# x             float64
# y             float64
# z             float64
# dtype: object

# %%
#Check if there are any NAN values in the dataset

df.isnull().values.any()
# Out:
# False

# %%
cut = df['cut']

# %%
#one hot encode the columns that need to be changed
# 0=Ideal, 1=Premium, 2=Good, 3=Very Good, 4=fair
df['cut'] = pd.factorize(df['cut'])[0]
df['cut']
# Out:
# 0        0
# 1        1
# 2        2
# 3        1
# 4        2
#         ..
# 53935    0
# 53936    2
# 53937    3
# 53938    1
# 53939    0
# Name: cut, Length: 53940, dtype: int64

# %%
color = df['color']

# %%
# E=0, I=1, J=2, H=3, F=4, G=5, D=6 
df['color'] = pd.factorize(df['color'])[0]
df['color']
# Out:
# 0        0
# 1        0
# 2        0
# 3        1
# 4        2
#         ..
# 53935    6
# 53936    6
# 53937    6
# 53938    3
# 53939    6
# Name: color, Length: 53940, dtype: int64

# %%
clarity = df['clarity']

# %%
# SI2=0, SI1=1, VS1=2, VS2=3, VVS2=4, VVS1=5, I1=6, IF=7
df['clarity'] = pd.factorize(df['clarity'])[0]
df['clarity']
# Out:
# 0        0
# 1        1
# 2        2
# 3        3
# 4        0
#         ..
# 53935    1
# 53936    1
# 53937    1
# 53938    0
# 53939    0
# Name: clarity, Length: 53940, dtype: int64

# %%
df.pop(df.columns[0])
df
# Out:
#        carat  cut  color  clarity  depth  table  price     x     y     z
# 0       0.23    0      0        0   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    1      0        1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23    2      0        2   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    1      1        3   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31    2      2        0   63.3   58.0    335  4.34  4.35  2.75
# ...      ...  ...    ...      ...    ...    ...    ...   ...   ...   ...
# 53935   0.72    0      6        1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72    2      6        1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70    3      6        1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    1      3        0   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75    0      6        0   62.2   55.0   2757  5.83  5.87  3.64
#
# [53940 rows x 10 columns]

# %%
corr = df.corr()
corr.style.background_gradient(cmap='BrBG_r')
# Out:
# <style type="text/css">
# #T_13c3f_row0_col0, #T_13c3f_row1_col1, #T_13c3f_row2_col2, #T_13c3f_row3_col3, #T_13c3f_row4_col4, #T_13c3f_row5_col5, #T_13c3f_row6_col6, #T_13c3f_row7_col7, #T_13c3f_row8_col8, #T_13c3f_row9_col9 {
#   background-color: #543005;
#   color: #f1f1f1;
# }
# #T_13c3f_row0_col1, #T_13c3f_row3_col4, #T_13c3f_row7_col4 {
#   background-color: #3b9b93;
#   color: #f1f1f1;
# }
# #T_13c3f_row0_col2, #T_13c3f_row3_col0, #T_13c3f_row3_col1, #T_13c3f_row3_col6, #T_13c3f_row3_col7, #T_13c3f_row3_col8, #T_13c3f_row3_col9, #T_13c3f_row4_col5, #T_13c3f_row5_col4, #T_13c3f_row7_col3 {
#   background-color: #003c30;
#   color: #f1f1f1;
# }
# #T_13c3f_row0_col3 {
#   background-color: #004337;
#   color: #f1f1f1;
# }
# #T_13c3f_row0_col4 {
#   background-color: #5bb3a8;
#   color: #f1f1f1;
# }
# #T_13c3f_row0_col5, #T_13c3f_row5_col8, #T_13c3f_row8_col5 {
#   background-color: #b1e1da;
#   color: #000000;
# }
# #T_13c3f_row0_col6 {
#   background-color: #794608;
#   color: #f1f1f1;
# }
# #T_13c3f_row0_col7, #T_13c3f_row7_col0, #T_13c3f_row7_col8, #T_13c3f_row8_col7 {
#   background-color: #5d3506;
#   color: #f1f1f1;
# }
# #T_13c3f_row0_col8, #T_13c3f_row0_col9, #T_13c3f_row8_col0, #T_13c3f_row8_col9, #T_13c3f_row9_col0, #T_13c3f_row9_col8 {
#   background-color: #683c07;
#   color: #f1f1f1;
# }
# #T_13c3f_row1_col0, #T_13c3f_row1_col8 {
#   background-color: #87d0c5;
#   color: #000000;
# }
# #T_13c3f_row1_col2 {
#   background-color: #00493e;
#   color: #f1f1f1;
# }
# #T_13c3f_row1_col3 {
#   background-color: #167a72;
#   color: #f1f1f1;
# }
# #T_13c3f_row1_col4, #T_13c3f_row5_col0 {
#   background-color: #abdfd7;
#   color: #000000;
# }
# #T_13c3f_row1_col5 {
#   background-color: #f5f2ea;
#   color: #000000;
# }
# #T_13c3f_row1_col6 {
#   background-color: #23867e;
#   color: #f1f1f1;
# }
# #T_13c3f_row1_col7 {
#   background-color: #8ad1c6;
#   color: #000000;
# }
# #T_13c3f_row1_col9 {
#   background-color: #95d6cc;
#   color: #000000;
# }
# #T_13c3f_row2_col0 {
#   background-color: #258880;
#   color: #f1f1f1;
# }
# #T_13c3f_row2_col1 {
#   background-color: #015d54;
#   color: #f1f1f1;
# }
# #T_13c3f_row2_col3, #T_13c3f_row4_col1 {
#   background-color: #61b7ac;
#   color: #f1f1f1;
# }
# #T_13c3f_row2_col4 {
#   background-color: #4aa69d;
#   color: #f1f1f1;
# }
# #T_13c3f_row2_col5, #T_13c3f_row7_col1, #T_13c3f_row8_col1 {
#   background-color: #35978f;
#   color: #f1f1f1;
# }
# #T_13c3f_row2_col6 {
#   background-color: #046961;
#   color: #f1f1f1;
# }
# #T_13c3f_row2_col7 {
#   background-color: #31938b;
#   color: #f1f1f1;
# }
# #T_13c3f_row2_col8 {
#   background-color: #2d8f87;
#   color: #f1f1f1;
# }
# #T_13c3f_row2_col9 {
#   background-color: #2f9189;
#   color: #f1f1f1;
# }
# #T_13c3f_row3_col2 {
#   background-color: #016259;
#   color: #f1f1f1;
# }
# #T_13c3f_row3_col5, #T_13c3f_row6_col3 {
#   background-color: #0e726a;
#   color: #f1f1f1;
# }
# #T_13c3f_row4_col0 {
#   background-color: #52aca3;
#   color: #f1f1f1;
# }
# #T_13c3f_row4_col2 {
#   background-color: #01554b;
#   color: #f1f1f1;
# }
# #T_13c3f_row4_col3 {
#   background-color: #3e9d95;
#   color: #f1f1f1;
# }
# #T_13c3f_row4_col6 {
#   background-color: #086d65;
#   color: #f1f1f1;
# }
# #T_13c3f_row4_col7 {
#   background-color: #419f97;
#   color: #f1f1f1;
# }
# #T_13c3f_row4_col8, #T_13c3f_row8_col4 {
#   background-color: #389991;
#   color: #f1f1f1;
# }
# #T_13c3f_row4_col9, #T_13c3f_row9_col4 {
#   background-color: #81cec2;
#   color: #000000;
# }
# #T_13c3f_row5_col1 {
#   background-color: #ddefed;
#   color: #000000;
# }
# #T_13c3f_row5_col2 {
#   background-color: #00483d;
#   color: #f1f1f1;
# }
# #T_13c3f_row5_col3 {
#   background-color: #10746c;
#   color: #f1f1f1;
# }
# #T_13c3f_row5_col6 {
#   background-color: #4faaa1;
#   color: #f1f1f1;
# }
# #T_13c3f_row5_col7 {
#   background-color: #bce5df;
#   color: #000000;
# }
# #T_13c3f_row5_col9, #T_13c3f_row9_col5 {
#   background-color: #a0dad1;
#   color: #000000;
# }
# #T_13c3f_row6_col0 {
#   background-color: #754308;
#   color: #f1f1f1;
# }
# #T_13c3f_row6_col1 {
#   background-color: #1a7e76;
#   color: #f1f1f1;
# }
# #T_13c3f_row6_col2 {
#   background-color: #004e44;
#   color: #f1f1f1;
# }
# #T_13c3f_row6_col4, #T_13c3f_row9_col1 {
#   background-color: #44a299;
#   color: #f1f1f1;
# }
# #T_13c3f_row6_col5 {
#   background-color: #92d4ca;
#   color: #000000;
# }
# #T_13c3f_row6_col7 {
#   background-color: #844c09;
#   color: #f1f1f1;
# }
# #T_13c3f_row6_col8 {
#   background-color: #8d520b;
#   color: #f1f1f1;
# }
# #T_13c3f_row6_col9 {
#   background-color: #8f540c;
#   color: #f1f1f1;
# }
# #T_13c3f_row7_col2, #T_13c3f_row8_col2, #T_13c3f_row9_col2 {
#   background-color: #003f34;
#   color: #f1f1f1;
# }
# #T_13c3f_row7_col5 {
#   background-color: #b9e4de;
#   color: #000000;
# }
# #T_13c3f_row7_col6 {
#   background-color: #8b500a;
#   color: #f1f1f1;
# }
# #T_13c3f_row7_col9, #T_13c3f_row9_col7 {
#   background-color: #5f3606;
#   color: #f1f1f1;
# }
# #T_13c3f_row8_col3, #T_13c3f_row9_col3 {
#   background-color: #003e32;
#   color: #f1f1f1;
# }
# #T_13c3f_row8_col6 {
#   background-color: #955910;
#   color: #f1f1f1;
# }
# #T_13c3f_row9_col6 {
#   background-color: #975b12;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_13c3f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_13c3f_level0_col0" class="col_heading level0 col0" >carat</th>
#       <th id="T_13c3f_level0_col1" class="col_heading level0 col1" >cut</th>
#       <th id="T_13c3f_level0_col2" class="col_heading level0 col2" >color</th>
#       <th id="T_13c3f_level0_col3" class="col_heading level0 col3" >clarity</th>
#       <th id="T_13c3f_level0_col4" class="col_heading level0 col4" >depth</th>
#       <th id="T_13c3f_level0_col5" class="col_heading level0 col5" >table</th>
#       <th id="T_13c3f_level0_col6" class="col_heading level0 col6" >price</th>
#       <th id="T_13c3f_level0_col7" class="col_heading level0 col7" >x</th>
#       <th id="T_13c3f_level0_col8" class="col_heading level0 col8" >y</th>
#       <th id="T_13c3f_level0_col9" class="col_heading level0 col9" >z</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_13c3f_level0_row0" class="row_heading level0 row0" >carat</th>
#       <td id="T_13c3f_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_13c3f_row0_col1" class="data row0 col1" >0.114426</td>
#       <td id="T_13c3f_row0_col2" class="data row0 col2" >-0.065386</td>
#       <td id="T_13c3f_row0_col3" class="data row0 col3" >-0.281218</td>
#       <td id="T_13c3f_row0_col4" class="data row0 col4" >0.028224</td>
#       <td id="T_13c3f_row0_col5" class="data row0 col5" >0.181618</td>
#       <td id="T_13c3f_row0_col6" class="data row0 col6" >0.921591</td>
#       <td id="T_13c3f_row0_col7" class="data row0 col7" >0.975094</td>
#       <td id="T_13c3f_row0_col8" class="data row0 col8" >0.951722</td>
#       <td id="T_13c3f_row0_col9" class="data row0 col9" >0.953387</td>
#     </tr>
#     <tr>
#       <th id="T_13c3f_level0_row1" class="row_heading level0 row1" >cut</th>
#       <td id="T_13c3f_row1_col0" class="data row1 col0" >0.114426</td>
#       <td id="T_13c3f_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_13c3f_row1_col2" class="data row1 col2" >-0.029128</td>
#       <td id="T_13c3f_row1_col3" class="data row1 col3" >-0.118670</td>
#       <td id="T_13c3f_row1_col4" class="data row1 col4" >0.169916</td>
#       <td id="T_13c3f_row1_col5" class="data row1 col5" >0.381988</td>
#       <td id="T_13c3f_row1_col6" class="data row1 col6" >0.049421</td>
#       <td id="T_13c3f_row1_col7" class="data row1 col7" >0.105361</td>
#       <td id="T_13c3f_row1_col8" class="data row1 col8" >0.105319</td>
#       <td id="T_13c3f_row1_col9" class="data row1 col9" >0.126726</td>
#     </tr>
#     <tr>
#       <th id="T_13c3f_level0_row2" class="row_heading level0 row2" >color</th>
#       <td id="T_13c3f_row2_col0" class="data row2 col0" >-0.065386</td>
#       <td id="T_13c3f_row2_col1" class="data row2 col1" >-0.029128</td>
#       <td id="T_13c3f_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_13c3f_row2_col3" class="data row2 col3" >0.032589</td>
#       <td id="T_13c3f_row2_col4" class="data row2 col4" >-0.001665</td>
#       <td id="T_13c3f_row2_col5" class="data row2 col5" >-0.033998</td>
#       <td id="T_13c3f_row2_col6" class="data row2 col6" >-0.016560</td>
#       <td id="T_13c3f_row2_col7" class="data row2 col7" >-0.055268

# %%
from sklearn.model_selection import train_test_split
y = df['price']
col = 'price'
X = df.loc[:, df.columns != col]

rem_X, test_X, rem_y, test_y = train_test_split(X,y, test_size=0.1, random_state=42, shuffle=True)
train_X, valid_X, train_y, valid_y = train_test_split(rem_X, rem_y, test_size=0.2)

# %%
print(test.shape)
print(train.shape)
print(valid.shape)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 print(test.shape)
#       2 print(train.shape)
#       3 print(valid.shape)
#
# NameError: name 'test' is not defined

# %%
# y_train = train['price']
# X_train = train.drop('price', inplace=True, axis=1)
# y_valid = valid['price']
# X_valid = valid.drop('price', inplace=True, axis=1)
# y_test = test['price']
# X_test = test.drop('price', inplace=True, axis=1)

# %%
X_train
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 X_train
#
# NameError: name 'X_train' is not defined

# %%
import pickle as pk
from sklearn.ensemble import GradientBoostingRegressor
n = 20
compiled_models = []


losss = ['squared_error', 'absolute_error', 'huber', 'quantile']
learning_rates = [0.1, 0.2, 0.3, 0.5]
n_estimatorss = [100, 200, 300, 400]
subsamples = [0.01, 0.5, 0.99]
criterions = ['friedman_mse', 'squared_error']
max_depths = [3, 5, 7]
max_featuress = ['auto', 'sqrt', 'log2']
warm_starts = [True, False]

counter = 0

for loss in losss:
    for learning_rate in learning_rates:
        for n_estimators in n_estimatorss:
            for subsample in subsamples:
                for criterion in criterions:
                    for max_depth in max_depths:
                        for max_features in max_featuress:
                            for warm_start in warm_starts:
                        
                                print(f"Compiled Model: {counter}\n")

                                try:
                                    model = GradientBoostingRegressor(loss=loss, 
                                                               learning_rate = learning_rate, 
                                                               n_estimators = n_estimators, 
                                                               subsample = subsample, 
                                                               criterion = criterion, 
                                                               max_depth = max_depth, 
                                                               max_features = max_features, 
                                                               warm_start = warm_start).fit(train_X, train_y)
                                except:
                                    counter += 1
                                    continue

                                compiled_models.append([float(model.score(valid_X, valid_y)), model])
                                counter += 1
                        
                        
compiled_models.sort(key=lambda row: (row[0]))
compiled_models = compiled_models[::-1]
compiled_models = compiled_models[0:n]

for i, model in enumerate(compiled_models):
    print(model[0], model[1])
    filename = f'PIKLE/GradientBoostingRegressor_{i}'
    pk.dump(model[1], open(filename, 'wb'))

# %%
file = open('PIKLE\GradientBoostingRegressor_0', 'rb')
modelN = pk.load(file)
file.close()

# %%
modelN.score(test_X, test_y)
# Out:
# 0.9808831923699913
